# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
unique_counts = application_df.nunique()
print(unique_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Set a cutoff value for the number of occurrences for an application type to be considered "rare"

cutoff = 500

# Determine which values to replace
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

# Check to make sure binning was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts > 1 for binning
classification_counts_gt1 = classification_counts[classification_counts > 1]
print(classification_counts_gt1)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 200

# Determine which values to replace
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < cutoff].index)

# Check if classifications_to_replace is empty
if classifications_to_replace:
    # Replace in dataframe
    for cls in classifications_to_replace:
        application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

   # Check to make sure binning was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# Display the first few rows of the modified dataframe
print(application_df.head())
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 46 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"]
X = application_df.drop(columns=["IS_SUCCESSFUL"])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Display the shapes of the training and testing sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (25724, 45) (8575, 45) (25724,) (8575,)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 20
hidden_nodes_layer4 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# C:\Users\r_mat\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 100)                 │           4,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │           1,020 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,891 (42.54 KB)
#  Trainable params: 10,891 (42.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_path = "checkpoints/weights.{epoch:02d}.model.keras"

cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=False,
    save_freq=5
)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=150, callbacks=[cp_callback])
# Out:
# Epoch 1/150
#   1/804 ━━━━━━━━━━━━━━━━━━━━ 11:00 822ms/step - accuracy: 0.2188 - loss: 0.7543
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  10/804 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4612 - loss: 0.7109
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  21/804 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5246 - loss: 0.6996
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  33/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5567 - loss: 0.6924
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  45/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5766 - loss: 0.6870
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  59/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5931 - loss: 0.6810
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  70/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6037 - loss: 0.6764
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  83/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6146 - loss: 0.6709
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  95/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6230 - loss: 0.6664
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 108/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6303 - loss: 0.6621
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 120/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6361 - loss: 0.6583
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 133/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6418 - loss: 0.6543
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7427 - loss: 0.5381
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 422/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7426 - loss: 0.5383
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 437/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7424 - loss: 0.5386
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 452/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7422 - loss: 0.5388
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 467/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7421 - loss: 0.5391
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 482/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7419 - loss: 0.5393
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 497/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7418 - loss: 0.5395
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 512/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7417 - loss: 0.5397
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 522/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7416 - loss: 0.5398
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 532/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7415 - loss: 0.5400
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 542/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7414 - loss: 0.5401
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 548/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7413 - loss: 0.5402
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 557/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7412 - loss: 0.5403
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 569/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7411 - loss: 0.5405
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 582/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7410 - loss: 0.5407
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 597/804 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7408 - loss: 0.5409
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 612/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7407 - loss: 0.5411
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 627/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7405 - loss: 0.5413
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 642/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7404 - loss: 0.5415
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 657/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7402 - loss: 0.5417
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 672/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7401 - loss: 0.5419
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 687/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7400 - loss: 0.5420
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 697/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7399 - loss: 0.5421
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 710/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7398 - loss: 0.5423
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 717/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7397 - loss: 0.5424
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 727/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7396 - loss: 0.5425
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 735/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7395 - loss: 0.5426
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 739/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7395 - loss: 0.5426
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 747/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7394 - loss: 0.5427
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 757/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7393 - loss: 0.5428
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 772/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7392 - loss: 0.5430
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 787/804 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7391 - loss: 0.5431
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
#
# Epoch 3: saving model to checkpoints/weights.03.model.keras
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7389 - loss: 0.5433
# Epoch 4/150
#   1/804 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6562 - loss: 0.6106
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  13/804 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6875 - loss: 0.5882
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  28/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7027 - loss: 0.5673
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  43/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7097 - loss: 0.5623
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  58/804 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7138 - loss: 0.5603
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  73/804 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7173 - loss: 0.5579
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#  88/804 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7206 - loss: 0.5559
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 103/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7235 - loss: 0.5538
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 118/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7262 - loss: 0.5519
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 133/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7281 - loss: 0.5506
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 148/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7298 - loss: 0.5494
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 163/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7311 - loss: 0.5484
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 178/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7319 - loss: 0.5478
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 193/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7324 - loss: 0.5473
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 208/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7327 - loss: 0.5470
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 223/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7331 - loss: 0.5467
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 238/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7334 - loss: 0.5464
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# Epoch 4: saving model to checkpoints/weights.04.model.keras
# 253/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7335 - loss: 0.5463
# Epoch 4: saving model to checkpoints/weights.04.model.keras
#
# ...
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
# 758/804 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7414 - loss: 0.5318
# Epoch 149: saving model to checkpoints/weights.149.model.keras
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
# 773/804 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7414 - loss: 0.5318
# Epoch 149: saving model to checkpoints/weights.149.model.keras
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
# 788/804 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7414 - loss: 0.5318
# Epoch 149: saving model to checkpoints/weights.149.model.keras
#
# Epoch 149: saving model to checkpoints/weights.149.model.keras
# Epoch 149: saving model to checkpoints/weights.149.model.keras
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.