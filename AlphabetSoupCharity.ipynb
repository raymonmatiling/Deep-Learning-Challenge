# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
unique_counts = application_df.nunique()
print(unique_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Set a cutoff value for the number of occurrences for an application type to be considered "rare"

cutoff = 500

# Determine which values to replace
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(application_counts[application_counts < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

# Check to make sure binning was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts > 1 for binning
classification_counts_gt1 = classification_counts[classification_counts > 1]
print(classification_counts_gt1)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 1000

# Determine which values to replace
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure binning was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with pd.get_dummies
application_df = pd.get_dummies(application_df)

# Display the first few rows of the modified dataframe
print(application_df.head())
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"]
X = application_df.drop(columns=["IS_SUCCESSFUL"])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Display the shapes of the training and testing sets
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (25724, 43) (8575, 43) (25724,) (8575,)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# C:\Users\r_mat\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 80)                  │           3,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 30)                  │           2,430 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,981 (23.36 KB)
#  Trainable params: 5,981 (23.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_path = "checkpoints/weights.{epoch:02d}.model.keras"

cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=False,
    save_freq=5
)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
# Out:
# Epoch 1/100
#   1/804 ━━━━━━━━━━━━━━━━━━━━ 9:08 683ms/step - accuracy: 0.4375 - loss: 0.8803
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  10/804 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4495 - loss: 0.9180
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  20/804 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4742 - loss: 0.8756
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  25/804 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4854 - loss: 0.8572
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  35/804 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5034 - loss: 0.8287
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  45/804 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5194 - loss: 0.8075
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  58/804 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5381 - loss: 0.7858
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  71/804 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5543 - loss: 0.7684
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#  85/804 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5685 - loss: 0.7533
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 100/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5816 - loss: 0.7395
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 116/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5935 - loss: 0.7267
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 130/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6024 - loss: 0.7171
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 145/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6107 - loss: 0.7081
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 160/804 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6179 - loss: 0.7002
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 175/804 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6243 - loss: 0.6931
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 190/804 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6300 - loss: 0.6868
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 205/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6349 - loss: 0.6811
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 220/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6393 - loss: 0.6760
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 235/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6433 - loss: 0.6714
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 250/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6468 - loss: 0.6672
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 265/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6501 - loss: 0.6634
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 280/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6530 - loss: 0.6599
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 295/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6559 - loss: 0.6566
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 310/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6585 - loss: 0.6535
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 325/804 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6609 - loss: 0.6506
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 340/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6631 - loss: 0.6479
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 355/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6651 - loss: 0.6455
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 370/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6670 - loss: 0.6432
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 385/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6688 - loss: 0.6410
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 400/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6704 - loss: 0.6390
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 415/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6719 - loss: 0.6371
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 430/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6733 - loss: 0.6353
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 445/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6746 - loss: 0.6336
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
#
# Epoch 1: saving model to checkpoints/weights.01.model.keras
# 460/804 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.
804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7365 - loss: 0.5387
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 739/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7366 - loss: 0.5386
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 753/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7366 - loss: 0.5385
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 768/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.5385
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 778/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7368 - loss: 0.5384
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 788/804 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7368 - loss: 0.5384
# Epoch 99: saving model to checkpoints/weights.99.model.keras
#
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 798/804 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7369 - loss: 0.5384
# Epoch 99: saving model to checkpoints/weights.99.model.keras
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7369 - loss: 0.5383
# Epoch 100/100
#   1/804 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.6562 - loss: 0.6084
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  18/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7275 - loss: 0.5416
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  34/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7337 - loss: 0.5358
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  49/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7327 - loss: 0.5369
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  67/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7317 - loss: 0.5371
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  80/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7319 - loss: 0.5364
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#  97/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7331 - loss: 0.5351
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 113/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7345 - loss: 0.5338
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 129/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7353 - loss: 0.5335
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 147/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7359 - loss: 0.5332
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 164/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7367 - loss: 0.5327
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 184/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7375 - loss: 0.5323
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 201/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7381 - loss: 0.5319
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 219/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7389 - loss: 0.5313
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 239/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7394 - loss: 0.5309
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 259/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7398 - loss: 0.5307
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 279/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7402 - loss: 0.5305
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 299/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7405 - loss: 0.5303
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 319/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7407 - loss: 0.5302
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 339/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.5301
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 355/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.5302
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 374/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7409 - loss: 0.5302
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 394/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.5303
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 414/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.5304
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 434/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.5306
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 453/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7407 - loss: 0.5308
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 469/804 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7407 - loss: 0.5309
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 489/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7406 - loss: 0.5311
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 509/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5313
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 529/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5315
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 549/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5317
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 569/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5318
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 589/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5320
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 608/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5321
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 624/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5322
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 644/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5323
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 659/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5323
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 679/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5324
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 699/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5325
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 718/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5326
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 734/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5327
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 751/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5328
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 769/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7405 - loss: 0.5328
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 787/804 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5329
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
#
# Epoch 100: saving model to checkpoints/weights.100.model.keras
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7404 - loss: 0.5330

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - 2ms/step - accuracy: 0.7258 - loss: 0.5553
# Loss: 0.5553436875343323, Accuracy: 0.7258309125900269

# %%
# Save the model to an HDF5 file
nn.save("C:/Users/r_mat/Classwork/Module_Challenge/Module21_Challenge/AlphabetSoupCharity.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
